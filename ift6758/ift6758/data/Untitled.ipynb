# %%
from game_client import *

# %%
game = Game(game_id='2022030411')

# %%
game.clean
game.feat_eng_part2()
# Out:
# 0      19:09
# 1      18:31
# 2      18:19
# 3      18:16
# 4      18:10
#        ...
# 124    02:07
# 125    01:45
# 126    01:31
# 127    00:26
# 128    00:01
# Name: periodTimeRemaining, Length: 129, dtype: object
#                blockingPlayerId                shootingPlayerId      gamePk  \
# 0    Aleksander Barkov|blocking  Jonathan Marchessault|shooting  2022030411
# 1                           NaN            Josh Mahura|shooting  2022030411
# 2                           NaN       William Karlsson|shooting  2022030411
# 3                           NaN         Michael Amadio|shooting  2022030411
# 4                           NaN       Alex Pietrangelo|shooting  2022030411
# ..                          ...                             ...         ...
# 124                         NaN           Sam Reinhart|shooting  2022030411
# 125                         NaN                             NaN  2022030411
# ...

# %%
game.clean.head(1000)
# Out:
#                blockingPlayerId                shootingPlayerId      gamePk  \
# 0    Aleksander Barkov|blocking  Jonathan Marchessault|shooting  2022030411
# 1                           NaN            Josh Mahura|shooting  2022030411
# 2                           NaN       William Karlsson|shooting  2022030411
# 3                           NaN         Michael Amadio|shooting  2022030411
# 4                           NaN       Alex Pietrangelo|shooting  2022030411
# ..                          ...                             ...         ...
# 124                         NaN           Sam Reinhart|shooting  2022030411
# 125                         NaN                             NaN  2022030411
# 126                         NaN          Nicolas Hague|shooting  2022030411
# 127                         NaN            Colin White|shooting  2022030411
# 128                         NaN           Aaron Ekblad|shooting  2022030411
#
# ...
